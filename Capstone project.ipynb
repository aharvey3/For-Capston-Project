# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/9gegpsmnsoo25ikkbl4qzlvlyjbgxs5x.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Learning FourSquare API with Python</font></h1>

# %% [markdown]
# ## Introduction
#
# In this study, we will take a closer look at the Atlanta and metro Atlanta area, specifically BBQ restaurants in the area. We will gauge the latitude and longitude of the Bank of America building in Atlanta, then look for all BBQ restaurants within a 6.2 mile radius. With these results, we should be able to ascertain which district or neighborhood would benefit the most in starting a BBQ restaurant business.

# %% [markdown]
# DATA:
# First, in order to come up with all of the BBQ restaurants within a 6.2 mile radius, we must use the Foursquare API model to locate where those particular restaurants occur. Using this data, we then can infer which neighborhoods are lacking in such enterprises. Thirdly, using this knowledge, we can then gather analysis on which neighborhood would be suitable. Research on Wikipedia's website, https://en.wikipedia.org/wiki/Neighborhoods_in_Atlanta in addition to this website, http://www.city-data.com/income/income-Atlanta-Georgia.html will give us an idea of any high schools, universities, parks, and all socioeconomics factors that will factor in the decision to start a new BBQ restaurant.

# %% [markdown]
# Methodology: You can see below the methodology taken. First, we import the necessary libraries into the Jupyter framework. Then using the foursquare agent we can find the latitude and longitude of the Bank of America building which is considered by many to be the center and downtown portion of the city. Following that, we have received all of the listed names, addresses and locations of restaurants. We then will put it in a panda frame, then we will categorize the data only using the relevant names and addresses, which is what we can now see in a nice, clear graph. Then we will visualize the map also indicating where it is with a red dot. This now give us relevant information. Now we can research the neighborhoods and incomes in and around the city of Atlanta using the websites listed.

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
#   - defaults/linux-64::pywavelets==1.0.0=py37hdd07704_0
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.19.0               |             py_0          53 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          85 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#
# The following packages will be UPDATED:
#
#   geopy              conda-forge/linux-64::geopy-1.11.0-py~ --> conda-forge/noarch::geopy-1.19.0-py_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.19.0         | 53 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata: done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
#   - defaults/linux-64::pywavelets==1.0.0=py37hdd07704_0
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
# done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'KBDUR2NLNAQKDGHU0WLORAEK01PPVEG4SEVCFTR5TPFP2KOY' # your Foursquare ID
CLIENT_SECRET = 'CHDLHVRGMNOR4VVMSVEJ2AQJ4SZ3N11ADVTGCTZ0MWK02LNV' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KBDUR2NLNAQKDGHU0WLORAEK01PPVEG4SEVCFTR5TPFP2KOY
# CLIENT_SECRET:CHDLHVRGMNOR4VVMSVEJ2AQJ4SZ3N11ADVTGCTZ0MWK02LNV

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '600 Peachtree St NE Atlanta GA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.7708618 -84.3861407005019

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving BBQ. So, let's define a query to search for Barbecue that is within 10000 metres from the Bank of America building in downtown Atlanta.

# %%
search_query = 'BBQ'
radius = 10000
print(search_query + ' .... OK!')
# Out:
# BBQ .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KBDUR2NLNAQKDGHU0WLORAEK01PPVEG4SEVCFTR5TPFP2KOY&client_secret=CHDLHVRGMNOR4VVMSVEJ2AQJ4SZ3N11ADVTGCTZ0MWK02LNV&ll=33.7708618,-84.3861407005019&v=20180604&query=BBQ&radius=10000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cd2cd81351e3d1d5400915e'},
#  'response': {'venues': [{'id': '54a2e686498e8fb585f023b2',
#     'name': 'Twin Smokers BBQ',
#     'location': {'address': '300 Marietta St NW',
#      'crossStreet': 'Baker St NW',
#      'lat': 33.761628323371944,
#      'lng': -84.3961784545938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.761628323371944,
#        'lng': -84.3961784545938}],
#      'distance': 1385,
#      'postalCode': '30313',
#      'cc': 'US',
#      'neighborhood': 'Downtown Atlanta',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['300 Marietta St NW (Baker St NW)',
#       'Atlanta, GA 30313',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '112542456'},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4b05768bf964a5207f5822e3',
#     'name': 'Community Q BBQ',
#     'location': {'address': '1361 Clairmont Rd',
#      'crossStreet': 'btwn Powell Ln & Ladson St',
#      'lat': 33.79254337071794,
#      'lng': -84.30525837463979,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.79254337071794,
#        'lng': -84.30525837463979}],
#      'distance': 7863,
#      'postalCode': '30033',
#      'cc': 'US',
#      'city': 'Decatur',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['1361 Clairmont Rd (btwn Powell Ln & Ladson St)',
#       'Decatur, GA 30033',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '582112cc1ff7967c19ed4be3',
#     'name': 'L&M Korean BBQ',
#     'location': {'address': '785 Argonne Ave NE',
#      'crossStreet': '6th street., NE',
#      'lat': 33.776094,
#      'lng': -84.377516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.776094,
#        'lng': -84.377516}],
#      'distance': 988,
#      'postalCode': '30308',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['785 Argonne Ave NE (6th street., NE)',
#       'Atlanta, GA 30308',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '56970b36498e3477e3dafda2',
#     'name': 'Hyatt House BBQ pit',
#     'location': {'lat': 33.76456,
#      'lng': -84.397204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.76456,
#        'lng': -84.397204}],
#      'distance': 1241,
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Atlanta, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d133951735',
#       'name': 'Roof Deck',
#       'pluralName': 'Roof Decks',
#       'shortName': 'Roof Deck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_roofdeck_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '51f4450a498e64a84d4fbdd0',
#     'name': 'Creative Loafing Rock N Soul BBQ',
#     'location': {'address': '695 North ave',
#      'crossStreet': 'Angier Ave',
#      'lat': 33.781261391469954,
#      'lng': -84.39075534328464,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.781261391469954,
#        'lng': -84.39075534328464}],
#      'distance': 1233,
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['695 North ave (Angier Ave)',
#       'Atlanta, GA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '56720bf9498e7b7f87eacda9',
#     'name': 'Bone Lick BBQ',
#     'location': {'address': '327 Edgewood Ave NE',
#      'lat': 33.754281456768354,
#      'lng': -84.37699238194318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.754281456768354,
#        'lng': -84.37699238194318}],
#      'distance': 2030,
#      'postalCode': '30312',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['327 Edgewood Ave NE',
#       'Atlanta, GA 30312',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4dc576752271f270512d43f3',
#     'name': 'Pig-N-Chik BBQ',
#     'location': {'address': '1815 Briarcliff Rd NE',
#      'crossStreet': 'at Clifton Rd NE',
#      'lat': 33.80566351093064,
#      'lng': -84.3360644555519,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.80566351093064,
#        'lng': -84.3360644555519}],
#      'distance': 6039,
#      'postalCode': '30329',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['1815 Briarcliff Rd NE (at Clifton Rd NE)',
#       'Atlanta, GA 30329',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '414102',
#      'url': 'https://www.grubhub.com/restaurant/pig-n-chik-1815-briarcliff-rd-atlanta/414102?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=414102',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '515e27c9e4b07ee8b44d1681',
#     'name': 'BBQ Lounge',
#     'location': {'address': '262 Edgewood Ave NE',
#      'lat': 33.75391319463552,
#      'lng': -84.39909862388132,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.75391319463552,
#        'lng': -84.39909862388132}],
#      'distance': 2235,
#      'postalCode': '30303',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['262 Edgewood Ave NE',
#       'Atlanta, GA 30303',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4c740031db52b1f75bd074dc',
#     'name': 'Georgia Best Bento BBQ',
#     'location': {'address': '50 Broad Street',
#      'lat': 33.7556796,
#      'lng': -84.389744,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.7556796,
#        'lng': -84.389744}],
#      'distance': 1722,
#      'postalCode': '30303',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['50 Broad Street',
#       'Atlanta, GA 30303',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '589a12bb80e1af7cfe810d37',
#     'name': 'Sweeetz Smokez BBQ',
#     'location': {'address': '336 McDaniel St SW',
#      'lat': 33.74557465411114,
#      'lng': -84.40547525882721,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.74557465411114,
#        'lng': -84.40547525882721}],
#      'distance': 3335,
#      'postalCode': '30313',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['336 McDaniel St SW',
#       'Atlanta, GA 30313',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '358962',
#      'url': 'https://www.grubhub.com/restaurant/cz-smokez-bbq-336-mcdaniel-st-sw-atlanta/358962?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=358962',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4f9994e6e4b02dd3853b0686',
#     'name': 'Sweet Auburn BBQ Food Truck',
#     'location': {'address': '1850 Howell Mill Road',
#      'lat': 33.7541204437447,
#      'lng': -84.380116715106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.7541204437447,
#        'lng': -84.380116715106}],
#      'distance': 1945,
#      'postalCode': '30318',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['1850 Howell Mill Road',
#       'Atlanta, GA 30318',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '5866eaee98f8aa281b68ddaf',
#     'name': 'Das BBQ',
#     'location': {'address': '1203 Collier Rd NW',
#      'lat': 33.811486221910954,
#      'lng': -84.42552166757224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.811486221910954,
#        'lng': -84.42552166757224}],
#      'distance': 5807,
#      'postalCode': '30318',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['1203 Collier Rd NW',
#       'Atlanta, GA 30318',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4d9cab3b8efaa143bcf252b7',
#     'name': 'Thumbs Up Smokehouse',
#     'location': {'address': '581 Edegwood',
#      'crossStreet': 'Randolph',
#      'lat': 33.75424853338035,
#      'lng': -84.36843038907473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.75424853338035,
#        'lng': -84.36843038907473}],
#      'distance': 2471,
#      'postalCode': '30312',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['581 Edegwood (Randolph)',
#       'Atlanta, GA 30312',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '598cf30b3b83073f81c9ed8f',
#     'name': 'Buckhead BBQ',
#     'location': {'address': '25 Irby Ave NW',
#      'lat': 33.841169,
#      'lng': -84.379848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.841169,
#        'lng': -84.379848}],
#      'distance': 7848,
#      'postalCode': '30305',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['25 Irby Ave NW',
#       'Atlanta, GA 30305',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '5b90b011f1fdaf0039591aa9',
#     'name': 'D 92 Korean BBQ',
#     'location': {'address': '225 E Trinity Pl',
#      'lat': 33.772139,
#      'lng': -84.294069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.772139,
#        'lng': -84.294069}],
#      'distance': 8521,
#      'postalCode': '30030',
#      'cc': 'US',
#      'city': 'Decatur',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['225 E Trinity Pl',
#       'Decatur, GA 30030',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '5281001f498eb2bcff510fe3',
#     'name': 'Lovies BBQ',
#     'location': {'address': '3420 Piedmont Rd NE Ste B',
#      'lat': 33.84800239167077,
#      'lng': -84.37405957770258,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.84800239167077,
#        'lng': -84.37405957770258}],
#      'distance': 8659,
#      'postalCode': '30305',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['3420 Piedmont Rd NE Ste B',
#       'Atlanta, GA 30305',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '734147',
#      'url': 'https://www.grubhub.com/restaurant/lovies-bbq-3420-piedmont-rd-ne-ste-b-atlanta/734147?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=734147',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '1358199197'},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '57ab6570498e64d07040fe90',
#     'name': 'The Greater Good BBQ',
#     'location': {'address': '2371 Hosea L Williams Dr NE',
#      'lat': 33.75131176348497,
#      'lng': -84.30996511312173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.75131176348497,
#        'lng': -84.30996511312173}],
#      'distance': 7378,
#      'postalCode': '30317',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['2371 Hosea L Williams Dr NE',
#       'Atlanta, GA 30317',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '52c70706498e02973fa0cfde',
#     'name': 'D.C. Wings & BBQ',
#     'location': {'address': '3083 Martin Luther King Jr Dr SW',
#      'crossStreet': 'Lynhurst',
#      'lat': 33.76134429854093,
#      'lng': -84.48594503908976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.76134429854093,
#        'lng': -84.48594503908976}],
#      'distance': 9296,
#      'postalCode': '30311',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['3083 Martin Luther King Jr Dr SW (Lynhurst)',
#       'Atlanta, GA 30311',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14c941735',
#       'name': 'Wings Joint',
#       'pluralName': 'Wings Joints',
#       'shortName': 'Wings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '57f97186498ee0d08be395a6',
#     'name': 'K BBQ Taco',
#     'location': {'address': '105 Clairemont Ave',
#      'lat': 33.775962,
#      'lng': -84.296389,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.775962,
#        'lng': -84.296389}],
#      'distance': 8324,
#      'postalCode': '30030',
#      'cc': 'US',
#      'city': 'Decatur',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['105 Clairemont Ave',
#       'Decatur, GA 30030',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '5232434311d2f2ca8fe76383',
#     'name': "Anna's BBQ",
#     'location': {'address': '1976 Hosea L Williams Dr NE',
#      'crossStreet': 'Howard St',
#      'lat': 33.75184119168383,
#      'lng': -84.32277817179295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.75184119168383,
#        'lng': -84.32277817179295}],
#      'distance': 6234,
#      'postalCode': '30317',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['1976 Hosea L Williams Dr NE (Howard St)',
#       'Atlanta, GA 30317',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '503228',
#      'url': 'https://www.grubhub.com/restaurant/annas-bbq-1976-hosea-l-williams-dr-ne-atlanta/503228?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=503228',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '5a1afbb2dee7706a7bf38412',
#     'name': 'Fox Bros Bar-B-Q & Brew',
#     'location': {'lat': 33.7556,
#      'lng': -84.399526,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.7556,
#        'lng': -84.399526}],
#      'distance': 2102,
#      'postalCode': '30313',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Atlanta, GA 30313', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4d6be2e971d3721e1d2e9706',
#     'name': 'Hodges BBQ',
#     'location': {'address': '2141 Candler Rd',
#      'lat': 33.72800353645525,
#      'lng': -84.28076836890594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.72800353645525,
#        'lng': -84.28076836890594}],
#      'distance': 10857,
#      'postalCode': '30032',
#      'cc': 'US',
#      'city': 'Atlanta-Decatur',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['2141 Candler Rd',
#       'Atlanta-Decatur, GA 30032',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4a3abcc5f964a5202ca01fe3',
#     'name': 'Waikikie Hawaiian BBQ',
#     'location': {'address': '2160 Briarcliff Rd NE',
#      'lat': 33.816644622373694,
#      'lng': -84.33554933974085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.816644622373694,
#        'lng': -84.33554933974085}],
#      'distance': 6919,
#      'postalCode': '30329',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['2160 Briarcliff Rd NE',
#       'Atlanta, GA 30329',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b79fe',
#       'name': 'Hawaiian Restaurant',
#       'pluralName': 'Hawaiian Restaurants',
#       'shortName': 'Hawaiian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '49f9eba0f964a520986d1fe3',
#     'name': 'Fox Bros. Bar-B-Q',
#     'location': {'address': '1238 Dekalb Ave NE',
#      'crossStreet': 'at Elmira Pl NE',
#      'lat': 33.76089344652857,
#      'lng': -84.34741290143242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.76089344652857,
#        'lng': -84.34741290143242}],
#      'distance': 3751,
#      'postalCode': '30307',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['1238 Dekalb Ave NE (at Elmira Pl NE)',
#       'Atlanta, GA 30307',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '152739631'},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '57dc6d45498e4bf3f5fcb601',
#     'name': "B's Cracklin BBQ",
#     'location': {'address': '2061 Main St NW',
#      'crossStreet': 'b/w Bolton Rd NW & Church St NW',
#      'lat': 33.81211,
#      'lng': -84.47189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.81211,
#        'lng': -84.47189}],
#      'distance': 9166,
#      'postalCode': '30318',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['2061 Main St NW (b/w Bolton Rd NW & Church St NW)',
#       'Atlanta, GA 30318',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '40e0b100f964a52019061fe3',
#     'name': "Daddy D'z",
#     'location': {'address': '264 Memorial Dr SE',
#      'lat': 33.74713709278917,
#      'lng': -84.37902989470064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.74713709278917,
#        'lng': -84.37902989470064}],
#      'distance': 2721,
#      'postalCode': '30312',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['264 Memorial Dr SE',
#       'Atlanta, GA 30312',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '53111d2d498e036dfa40273c',
#     'name': 'Sweet Auburn Barbecue',
#     'location': {'address': '656 N Highland Ave NE',
#      'crossStreet': 'at Blue Ridge Ave NE',
#      'lat': 33.772377925851195,
#      'lng': -84.35257814251861,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.772377925851195,
#        'lng': -84.35257814251861}],
#      'distance': 3110,
#      'postalCode': '30306',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['656 N Highland Ave NE (at Blue Ridge Ave NE)',
#       'Atlanta, GA 30306',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '86918907'},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '5500b3dc498e887caf1975e6',
#     'name': 'Tom, Dick & Hank',
#     'location': {'address': '191 Ralph David Abernathy Blvd SW',
#      'lat': 33.736978863320296,
#      'lng': -84.39414384328047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.736978863320296,
#        'lng': -84.39414384328047}],
#      'distance': 3843,
#      'postalCode': '30312',
#      'cc': 'US',
#      'neighborhood': 'Mechanicsville',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['191 Ralph David Abernathy Blvd SW',
#       'Atlanta, GA 30312',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4d69a1e9c1655481538aee81',
#     'name': "Moe's Original Bar B Que",
#     'location': {'address': '349 14th St NW',
#      'crossStreet': 'at State St.',
#      'lat': 33.78630197665889,
#      'lng': -84.39861977994629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.78630197665889,
#        'lng': -84.39861977994629}],
#      'distance': 2070,
#      'postalCode': '30318',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['349 14th St NW (at State St.)',
#       'Atlanta, GA 30318',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1046136',
#      'url': 'https://www.grubhub.com/restaurant/moes-original-bbq-349-14th-st-nw-atlanta/1046136?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1046136',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1557319041',
#     'hasPerk': False},
#    {'id': '4a35923ff964a520339d1fe3',
#     'name': 'D.B.A. Barbecue',
#     'location': {'address': '1190 N Highland Ave NE',
#      'crossStreet': 'Amsterdam Ave',
#      'lat': 33.78709077820011,
#      'lng': -84.35565054043161,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.78709077820011,
#        'lng': -84.35565054043161}],
#      'distance': 3350,
#      'postalCode': '30306',
#      'cc': 'US',
#      'city': 'Atlanta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['1190 N Highland Ave NE (Amsterdam Ave)',
#       'Atlanta, GA 30306',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '410189381'},
#     'referralId': 'v-1557319041',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                                                                                                                                                                                                                                 categories  \
# 0  [{'id': '4bf58dd8d48988d1df931735', 'name': 'BBQ Joint', 'pluralName': 'BBQ Joints', 'shortName': 'BBQ', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4bf58dd8d48988d1df931735', 'name': 'BBQ Joint', 'pluralName': 'BBQ Joints', 'shortName': 'BBQ', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '4bf58dd8d48988d113941735', 'name': 'Korean Restaurant', 'pluralName': 'Korean Restaurants', 'shortName': 'Korean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4bf58dd8d48988d133951735', 'name': 'Roof Deck', 'pluralName': 'Roof Decks', 'shortName': 'Roof Deck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_roofdeck_', 'suffix': '.png'}, 'primary': True}]
# 4  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'General Entertainment', 'pluralName': 'General Entertainment', 'shortName': 'Entertainment', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_', 'suffix': '.png'}, 'primary': True}]
#
#   delivery.id delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0  NaN         NaN                         NaN
# 1  NaN         NaN                         NaN
# 2  NaN         NaN                         NaN
# 3  NaN         NaN                         NaN
# 4  NaN         NaN                         NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0  NaN                          NaN                    NaN          False
# 1  NaN                          NaN                    NaN          False
# 2  NaN                          NaN                    NaN          False
# 3  NaN                          NaN                    NaN          False
# 4  NaN                          NaN                    NaN          False
#
#                          id    location.address  ...  \
# 0  54a2e686498e8fb585f023b2  300 Marietta St NW  ...
# 1  4b05768bf964a5207f5822e3  1361 Clairmont Rd   ...
# 2  582112cc1ff7967c19ed4be3  785 Argonne Ave NE  ...
# 3  56970b36498e3477e3dafda2  NaN                 ...
# 4  51f4450a498e64a84d4fbdd0  695 North ave       ...
#
#                                                             location.formattedAddress  \
# 0  [300 Marietta St NW (Baker St NW), Atlanta, GA 30313, United States]
# 1  [1361 Clairmont Rd (btwn Powell Ln & Ladson St), Decatur, GA 30033, United States]
# 2  [785 Argonne Ave NE (6th street., NE), Atlanta, GA 30308, United States]
# 3  [Atlanta, GA, United States]
# 4  [695 North ave (Angier Ave), Atlanta, GA, United States]
#
#                                                         location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 33.761628323371944, 'lng': -84.3961784545938}]
# 1  [{'label': 'display', 'lat': 33.79254337071794, 'lng': -84.30525837463979}]
# 2  [{'label': 'display', 'lat': 33.776094, 'lng': -84.377516}]
# 3  [{'label': 'display', 'lat': 33.76456, 'lng': -84.397204}]
# 4  [{'label': 'display', 'lat': 33.781261391469954, 'lng': -84.39075534328464}]
#
#   location.lat location.lng  location.neighborhood location.postalCode  \
# 0  33.761628   -84.396178    Downtown Atlanta       30313
# 1  33.792543   -84.305258    NaN                    30033
# 2  33.776094   -84.377516    NaN                    30308
# 3  33.764560   -84.397204    NaN                    NaN
# 4  33.781261   -84.390755    NaN                    NaN
#
#   location.state                              name    referralId venuePage.id
# 0  GA             Twin Smokers BBQ                  v-1557319041  112542456
# 1  GA             Community Q BBQ                   v-1557319041  NaN
# 2  GA             L&M Korean BBQ                    v-1557319041  NaN
# 3  GA             Hyatt House BBQ pit               v-1557319041  NaN
# 4  GA             Creative Loafing Rock N Soul BBQ  v-1557319041  NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                 name             categories  \
# 0   Twin Smokers BBQ                  BBQ Joint
# 1   Community Q BBQ                   BBQ Joint
# 2   L&M Korean BBQ                    Korean Restaurant
# 3   Hyatt House BBQ pit               Roof Deck
# 4   Creative Loafing Rock N Soul BBQ  General Entertainment
# 5   Bone Lick BBQ                     BBQ Joint
# 6   Pig-N-Chik BBQ                    BBQ Joint
# 7   BBQ Lounge                        BBQ Joint
# 8   Georgia Best Bento BBQ            Chinese Restaurant
# 9   Sweeetz Smokez BBQ                BBQ Joint
# 10  Sweet Auburn BBQ Food Truck       Food Truck
# 11  Das BBQ                           BBQ Joint
# 12  Thumbs Up Smokehouse              BBQ Joint
# 13  Buckhead BBQ                      BBQ Joint
# 14  D 92 Korean BBQ                   Korean Restaurant
# 15  Lovies BBQ                        BBQ Joint
# 16  The Greater Good BBQ              BBQ Joint
# 17  D.C. Wings & BBQ                  Wings Joint
# 18  K BBQ Taco                        Restaurant
# 19  Anna's BBQ                        BBQ Joint
# 20  Fox Bros Bar-B-Q & Brew           BBQ Joint
# 21  Hodges BBQ                        BBQ Joint
# 22  Waikikie Hawaiian BBQ             Hawaiian Restaurant
# 23  Fox Bros. Bar-B-Q                 BBQ Joint
# 24  B's Cracklin BBQ                  BBQ Joint
# 25  Daddy D'z                         BBQ Joint
# 26  Sweet Auburn Barbecue             BBQ Joint
# 27  Tom, Dick & Hank                  Restaurant
# 28  Moe's Original Bar B Que          BBQ Joint
# 29  D.B.A. Barbecue                   BBQ Joint
#
#                               address  cc             city        country  \
# 0   300 Marietta St NW                 US  Atlanta          United States
# 1   1361 Clairmont Rd                  US  Decatur          United States
# 2   785 Argonne Ave NE                 US  Atlanta          United States
# 3   NaN                                US  Atlanta          United States
# 4   695 North ave                      US  Atlanta          United States
# 5   327 Edgewood Ave NE                US  Atlanta          United States
# 6   1815 Briarcliff Rd NE              US  Atlanta          United States
# 7   262 Edgewood Ave NE                US  Atlanta          United States
# 8   50 Broad Street                    US  Atlanta          United States
# 9   336 McDaniel St SW                 US  Atlanta          United States
# 10  1850 Howell Mill Road              US  Atlanta          United States
# 11  1203 Collier Rd NW                 US  Atlanta          United States
# 12  581 Edegwood                       US  Atlanta          United States
# 13  25 Irby Ave NW                     US  Atlanta          United States
# 14  225 E Trinity Pl                   US  Decatur          United States
# 15  3420 Piedmont Rd NE Ste B          US  Atlanta          United States
# 16  2371 Hosea L Williams Dr NE        US  Atlanta          United States
# 17  3083 Martin Luther King Jr Dr SW   US  Atlanta          United States
# 18  105 Clairemont Ave                 US  Decatur          United States
# 19  1976 Hosea L Williams Dr NE        US  Atlanta          United States
# 20  NaN                                US  Atlanta          United States
# 21  2141 Candler Rd                    US  Atlanta-Decatur  United States
# 22  2160 Briarcliff Rd NE              US  Atlanta          United States
# 23  1238 Dekalb Ave NE                 US  Atlanta          United States
# 24  2061 Main St NW                    US  Atlanta          United States
# 25  264 Memorial Dr SE                 US  Atlanta          United States
# 26  656 N Highland Ave NE              US  Atlanta          United States
# 27  191 Ralph David Abernathy Blvd SW  US  Atlanta          United States
# 28  349 14th St NW                     US  Atlanta          United States
# 29  1190 N Highland Ave NE             US  Atlanta          United States
#
#                         crossStreet  distance  \
# 0   Baker St NW                      1385
# 1   btwn Powell Ln & Ladson St       7863
# 2   6th street., NE                  988
# 3   NaN                              1241
# 4   Angier Ave                       1233
# 5   NaN                              2030
# 6   at Clifton Rd NE                 6039
# 7   NaN                              2235
# 8   NaN                              1722
# 9   NaN                              3335
# 10  NaN                              1945
# 11  NaN                              5807
# 12  Randolph                         2471
# 13  NaN                              7848
# 14  NaN                              8521
# 15  NaN                              8659
# 16  NaN                              7378
# 17  Lynhurst                         9296
# 18  NaN                              8324
# 19  Howard St                        6234
# 20  NaN                              2102
# 21  NaN                              10857
# 22  NaN                              6919
# 23  at Elmira Pl NE                  3751
# 24  b/w Bolton Rd NW & Church St NW  9166
# 25  NaN                              2721
# 26  at Blue Ridge Ave NE             3110
# 27  NaN                              3843
# 28  at State St.                     2070
# 29  Amsterdam Ave                    3350
#
#                                                                          formattedAddress  \
# 0   [300 Marietta St NW (Baker St NW), Atlanta, GA 30313, United States]
# 1   [1361 Clairmont Rd (btwn Powell Ln & Ladson St), Decatur, GA 30033, United States]
# 2   [785 Argonne Ave NE (6th street., NE), Atlanta, GA 30308, United States]
# 3   [Atlanta, GA, United States]
# 4   [695 North ave (Angier Ave), Atlanta, GA, United States]
# 5   [327 Edgewood Ave NE, Atlanta, GA 30312, United States]
# 6   [1815 Briarcliff Rd NE (at Clifton Rd NE), Atlanta, GA 30329, United States]
# 7   [262 Edgewood Ave NE, Atlanta, GA 30303, United States]
# 8   [50 Broad Street, Atlanta, GA 30303, United States]
# 9   [336 McDaniel St SW, Atlanta, GA 30313, United States]
# 10  [1850 Howell Mill Road, Atlanta, GA 30318, United States]
# 11  [1203 Collier Rd NW, Atlanta, GA 30318, United States]
# 12  [581 Edegwood (Randolph), Atlanta, GA 30312, United States]
# 13  [25 Irby Ave NW, Atlanta, GA 30305, United States]
# 14  [225 E Trinity Pl, Decatur, GA 30030, United States]
# 15  [3420 Piedmont Rd NE Ste B, Atlanta, GA 30305, United States]
# 16  [2371 Hosea L Williams Dr NE, Atlanta, GA 30317, United States]
# 17  [3083 Martin Luther King Jr Dr SW (Lynhurst), Atlanta, GA 30311, United States]
# 18  [105 Clairemont Ave, Decatur, GA 30030, United States]
# 19  [1976 Hosea L Williams Dr NE (Howard St), Atlanta, GA 30317, United States]
# 20  [Atlanta, GA 30313, United States]
# 21  [2141 Candler Rd, Atlanta-Decatur, GA 30032, United States]
# 22  [2160 Briarcliff Rd NE, Atlanta, GA 30329, United States]
# 23  [1238 Dekalb Ave NE (at Elmira Pl NE), Atlanta, GA 30307, United States]
# 24  [2061 Main St NW (b/w Bolton Rd NW & Church St NW), Atlanta, GA 30318, United States]
# 25  [264 Memorial Dr SE, Atlanta, GA 30312, United States]
# 26  [656 N Highland Ave NE (at Blue Ridge Ave NE), Atlanta, GA 30306, United States]
# 27  [191 Ralph David Abernathy Blvd SW, Atlanta, GA 30312, United States]
# 28  [349 14th St NW (at State St.), Atlanta, GA 30318, United States]
# 29  [1190 N Highland Ave NE (Amsterdam Ave), Atlanta, GA 30306, United States]
#
#                                                                   labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 33.761628323371944, 'lng': -84.3961784545938}]
# 1   [{'label': 'display', 'lat': 33.79254337071794, 'lng': -84.30525837463979}]
# 2   [{'label': 'display', 'lat': 33.776094, 'lng': -84.377516}]
# 3   [{'label': 'display', 'lat': 33.76456, 'lng': -84.397204}]
# 4   [{'label': 'display', 'lat': 33.781261391469954, 'lng': -84.39075534328464}]
# 5   [{'label': 'display', 'lat': 33.754281456768354, 'lng': -84.37699238194318}]
# 6   [{'label': 'display', 'lat': 33.80566351093064, 'lng': -84.3360644555519}]
# 7   [{'label': 'display', 'lat': 33.75391319463552, 'lng': -84.39909862388132}]
# 8   [{'label': 'display', 'lat': 33.7556796, 'lng': -84.389744}]
# 9   [{'label': 'display', 'lat': 33.74557465411114, 'lng': -84.40547525882721}]
# 10  [{'label': 'display', 'lat': 33.7541204437447, 'lng': -84.380116715106}]
# 11  [{'label': 'display', 'lat': 33.811486221910954, 'lng': -84.42552166757224}]
# 12  [{'label': 'display', 'lat': 33.75424853338035, 'lng': -84.36843038907473}]
# 13  [{'label': 'display', 'lat': 33.841169, 'lng': -84.379848}]
# 14  [{'label': 'display', 'lat': 33.772139, 'lng': -84.294069}]
# 15  [{'label': 'display', 'lat': 33.84800239167077, 'lng': -84.37405957770258}]
# 16  [{'label': 'display', 'lat': 33.75131176348497, 'lng': -84.30996511312173}]
# 17  [{'label': 'display', 'lat': 33.76134429854093, 'lng': -84.48594503908976}]
# 18  [{'label': 'display', 'lat': 33.775962, 'lng': -84.296389}]
# 19  [{'label': 'display', 'lat': 33.75184119168383, 'lng': -84.32277817179295}]
# 20  [{'label': 'display', 'lat': 33.7556, 'lng': -84.399526}]
# 21  [{'label': 'display', 'lat': 33.72800353645525, 'lng': -84.28076836890594}]
# 22  [{'label': 'display', 'lat': 33.816644622373694, 'lng': -84.33554933974085}]
# 23  [{'label': 'display', 'lat': 33.76089344652857, 'lng': -84.34741290143242}]
# 24  [{'label': 'display', 'lat': 33.81211, 'lng': -84.47189}]
# 25  [{'label': 'display', 'lat': 33.74713709278917, 'lng': -84.37902989470064}]
# 26  [{'label': 'display', 'lat': 33.772377925851195, 'lng': -84.35257814251861}]
# 27  [{'label': 'display', 'lat': 33.736978863320296, 'lng': -84.39414384328047}]
# 28  [{'label': 'display', 'lat': 33.78630197665889, 'lng': -84.39861977994629}]
# 29  [{'label': 'display', 'lat': 33.78709077820011, 'lng': -84.35565054043161}]
#
#           lat        lng      neighborhood postalCode state  \
# 0   33.761628 -84.396178  Downtown Atlanta  30313      GA
# 1   33.792543 -84.305258  NaN               30033      GA
# 2   33.776094 -84.377516  NaN               30308      GA
# 3   33.764560 -84.397204  NaN               NaN        GA
# 4   33.781261 -84.390755  NaN               NaN        GA
# 5   33.754281 -84.376992  NaN               30312      GA
# 6   33.805664 -84.336064  NaN               30329      GA
# 7   33.753913 -84.399099  NaN               30303      GA
# 8   33.755680 -84.389744  NaN               30303      GA
# 9   33.745575 -84.405475  NaN               30313      GA
# 10  33.754120 -84.380117  NaN               30318      GA
# 11  33.811486 -84.425522  NaN               30318      GA
# 12  33.754249 -84.368430  NaN               30312      GA
# 13  33.841169 -84.379848  NaN               30305      GA
# 14  33.772139 -84.294069  NaN               30030      GA
# 15  33.848002 -84.374060  NaN               30305      GA
# 16  33.751312 -84.309965  NaN               30317      GA
# 17  33.761344 -84.485945  NaN               30311      GA
# 18  33.775962 -84.296389  NaN               30030      GA
# 19  33.751841 -84.322778  NaN               30317      GA
# 20  33.755600 -84.399526  NaN               30313      GA
# 21  33.728004 -84.280768  NaN               30032      GA
# 22  33.816645 -84.335549  NaN               30329      GA
# 23  33.760893 -84.347413  NaN               30307      GA
# 24  33.812110 -84.471890  NaN               30318      GA
# 25  33.747137 -84.379030  NaN               30312      GA
# 26  33.772378 -84.352578  NaN               30306      GA
# 27  33.736979 -84.394144  Mechanicsville    30312      GA
# 28  33.786302 -84.398620  NaN               30318      GA
# 29  33.787091 -84.355651  NaN               30306      GA
#
#                           id
# 0   54a2e686498e8fb585f023b2
# 1   4b05768bf964a5207f5822e3
# 2   582112cc1ff7967c19ed4be3
# 3   56970b36498e3477e3dafda2
# 4   51f4450a498e64a84d4fbdd0
# 5   56720bf9498e7b7f87eacda9
# 6   4dc576752271f270512d43f3
# 7   515e27c9e4b07ee8b44d1681
# 8   4c740031db52b1f75bd074dc
# 9   589a12bb80e1af7cfe810d37
# 10  4f9994e6e4b02dd3853b0686
# 11  5866eaee98f8aa281b68ddaf
# 12  4d9cab3b8efaa143bcf252b7
# 13  598cf30b3b83073f81c9ed8f
# 14  5b90b011f1fdaf0039591aa9
# 15  5281001f498eb2bcff510fe3
# 16  57ab6570498e64d07040fe90
# 17  52c70706498e02973fa0cfde
# 18  57f97186498ee0d08be395a6
# 19  5232434311d2f2ca8fe76383
# 20  5a1afbb2dee7706a7bf38412
# 21  4d6be2e971d3721e1d2e9706
# 22  4a3abcc5f964a5202ca01fe3
# 23  49f9eba0f964a520986d1fe3
# 24  57dc6d45498e4bf3f5fcb601
# 25  40e0b100f964a52019061fe3
# 26  53111d2d498e036dfa40273c
# 27  5500b3dc498e887caf1975e6
# 28  4d69a1e9c1655481538aee81
# 29  4a35923ff964a520339d1fe3

# %% [markdown]
# #### Let's visualize the BBQ restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0     Twin Smokers BBQ
# 1     Community Q BBQ
# 2     L&M Korean BBQ
# 3     Hyatt House BBQ pit
# 4     Creative Loafing Rock N Soul BBQ
# 5     Bone Lick BBQ
# 6     Pig-N-Chik BBQ
# 7     BBQ Lounge
# 8     Georgia Best Bento BBQ
# 9     Sweeetz Smokez BBQ
# 10    Sweet Auburn BBQ Food Truck
# 11    Das BBQ
# 12    Thumbs Up Smokehouse
# 13    Buckhead BBQ
# 14    D 92 Korean BBQ
# 15    Lovies BBQ
# 16    The Greater Good BBQ
# 17    D.C. Wings & BBQ
# 18    K BBQ Taco
# 19    Anna's BBQ
# 20    Fox Bros Bar-B-Q & Brew
# 21    Hodges BBQ
# 22    Waikikie Hawaiian BBQ
# 23    Fox Bros. Bar-B-Q
# 24    B's Cracklin BBQ
# 25    Daddy D'z
# 26    Sweet Auburn Barbecue
# 27    Tom, Dick & Hank
# 28    Moe's Original Bar B Que
# 29    D.B.A. Barbecue
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

#add a red mark to indicate the Bank of America building
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Results
